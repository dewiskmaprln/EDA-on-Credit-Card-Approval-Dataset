# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
app_df = pd.read_csv("application_record.csv")

# %%
app_df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %% [markdown]
# # EDA file App

# %%
app_df.describe().T
# Out:
#                     count          mean            std        min         25%  \
# ID                16900.0  5.330606e+06  512283.837956  5008804.0  5024287.75
# CNT_CHILDREN      16900.0  4.164497e-01       0.713502        0.0        0.00
# AMT_INCOME_TOTAL  16900.0  1.878017e+05  101395.225687    30150.0   121500.00
# DAYS_BIRTH        16899.0 -1.617231e+04    4184.567761   -25140.0   -19736.50
# DAYS_EMPLOYED     16899.0  6.557945e+04  143091.176053   -15072.0    -3202.00
# FLAG_MOBIL        16899.0  1.000000e+00       0.000000        1.0        1.00
# FLAG_WORK_PHONE   16899.0  1.906030e-01       0.392788        0.0        0.00
# FLAG_PHONE        16899.0  3.071779e-01       0.461337        0.0        0.00
# FLAG_EMAIL        16899.0  7.645423e-02       0.265731        0.0        0.00
# CNT_FAM_MEMBERS   16899.0  2.195870e+00       0.874599        1.0        2.00
#
#                         50%         75%        max
# ID                5041124.5  5471204.25  6820978.0
# ...

# %%
app_df["NAME_INCOME_TYPE"].describe().T
# Out:
# count       16900
# unique          5
# top       Working
# freq         8070
# Name: NAME_INCOME_TYPE, dtype: object

# %%
app_df["CNT_CHILDREN"].max()
# Out:
# 5

# %%
app_df[app_df["CNT_CHILDREN"] == 19]
# Out:
# Empty DataFrame
# Columns: [ID, CODE_GENDER, FLAG_OWN_CAR, FLAG_OWN_REALTY, CNT_CHILDREN, AMT_INCOME_TOTAL, NAME_INCOME_TYPE, NAME_EDUCATION_TYPE, NAME_FAMILY_STATUS, NAME_HOUSING_TYPE, DAYS_BIRTH, DAYS_EMPLOYED, FLAG_MOBIL, FLAG_WORK_PHONE, FLAG_PHONE, FLAG_EMAIL, OCCUPATION_TYPE, CNT_FAM_MEMBERS]
# Index: []

# %%
app_df[app_df["DAYS_BIRTH"] == -12005]
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          427500.0          Working    Higher education     Civil marriage
# 1          427500.0          Working    Higher education     Civil marriage
#
#   NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 0  Rented apartment    -12005.0        -4542.0         1.0              1.0
# 1  Rented apartment    -12005.0        -4542.0         1.0              1.0
#
#    FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 0         0.0         0.0             NaN              2.0
# 1         0.0         0.0             NaN              2.0

# %%
app_df[app_df["DAYS_EMPLOYED"] > 0]
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 7      5008812           F            N               Y             0
# 8      5008813           F            N               Y             0
# 9      5008814           F            N               Y             0
# 76     5008884           F            N               Y             0
# 160    5008974           F            N               Y             0
# ...        ...         ...          ...             ...           ...
# 16850  5048209           F            N               Y             0
# 16851  5048210           F            N               Y             0
# 16852  5048211           F            N               Y             0
# 16853  5048212           F            N               Y             0
# 16854  5048213           F            N               Y             0
#
#        AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
app_df.duplicated().sum()
# Out:
# 0

# %%
app_df.isna().sum()*100/len(app_df)
# Out:
# ID                      0.000000
# CODE_GENDER             0.000000
# FLAG_OWN_CAR            0.000000
# FLAG_OWN_REALTY         0.000000
# CNT_CHILDREN            0.000000
# AMT_INCOME_TOTAL        0.000000
# NAME_INCOME_TYPE        0.000000
# NAME_EDUCATION_TYPE     0.000000
# NAME_FAMILY_STATUS      0.005917
# NAME_HOUSING_TYPE       0.005917
# DAYS_BIRTH              0.005917
# DAYS_EMPLOYED           0.005917
# FLAG_MOBIL              0.005917
# FLAG_WORK_PHONE         0.005917
# FLAG_PHONE              0.005917
# FLAG_EMAIL              0.005917
# OCCUPATION_TYPE        31.142012
# CNT_FAM_MEMBERS         0.005917
# dtype: float64

# %%
plt.figure(figsize=(10,10))

cols_to_plot = ["CNT_CHILDREN","AMT_INCOME_TOTAL","DAYS_BIRTH","DAYS_EMPLOYED"]
app_df[cols_to_plot].hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)

# %%
fig, axes = plt.subplots(1,2)

g1=sns.countplot(x=app_df.NAME_INCOME_TYPE,linewidth=1.2, ax=axes[0])
g1.set_title("Customer Distribution by Income Type")
g1.set_xlabel("Income Type")

g2=sns.countplot(x=app_df.NAME_FAMILY_STATUS,linewidth=1.2, ax=axes[1], order = app_df["NAME_FAMILY_STATUS"].value_counts().index)
g2.set_title("Customer Distribution by Family Status")
g2.set_xlabel("Family Status")

fig.set_size_inches(14,5)

plt.tight_layout()


plt.show()

# %%
app_df["NAME_INCOME_TYPE"].value_counts(normalize=True)*100
# Out:
# Working                 47.751479
# Commercial associate    24.798817
# Pensioner               18.562130
# State servant            8.810651
# Student                  0.076923
# Name: NAME_INCOME_TYPE, dtype: float64

# %%
plt.figure(figsize=(10,8))
total = float(len(app_df))
ax = sns.countplot(x="NAME_INCOME_TYPE",  data=app_df)
plt.title('Data provided for each event', fontsize=20)
for p in ax.patches:
    percentage = '{:.3f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
plt.show()

# %%
app_df["NAME_INCOME_TYPE"].value_counts()
# Out:
# Working                 8070
# Commercial associate    4191
# Pensioner               3137
# State servant           1489
# Student                   13
# Name: NAME_INCOME_TYPE, dtype: int64

# %%
fig, axes = plt.subplots(1,2)

g1= sns.countplot(y=app_df.NAME_HOUSING_TYPE,linewidth=1.2, ax=axes[0], order = app_df["NAME_HOUSING_TYPE"].value_counts().index)
g1.set_title("Customer Distribution by Housing Type")
g1.set_xlabel("Count")
g1.set_ylabel("Housing Type")

g2= sns.countplot(y=app_df.NAME_EDUCATION_TYPE, ax=axes[1], order = app_df["NAME_EDUCATION_TYPE"].value_counts().index)
g2.set_title("Customer Distribution by Education")
g2.set_xlabel("Count")
g2.set_ylabel("Education Type")

fig.set_size_inches(14,5)

plt.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(1,3)

g1= app_df['CODE_GENDER'].value_counts().plot.pie(explode=[0.1,0.1], ax=axes[0])
g1.set_title("Customer Distribution by Gender")

g2= app_df['FLAG_OWN_CAR'].value_counts().plot.pie(explode=[0.1,0.1], ax=axes[1])
g2.set_title("Car Ownership")

g3= app_df['FLAG_OWN_REALTY'].value_counts().plot.pie(explode=[0.1,0.1], ax=axes[2])
g3.set_title("Realty Ownership")

fig.set_size_inches(14,5)

plt.tight_layout()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,8))

plt.pie(x=app_df["CODE_GENDER"].value_counts(), 
        autopct='%1.1f%%',
        shadow = True, 
        textprops={'fontsize': 15},
        startangle=30,
        explode = (0.1, 0.001),
        labels=["Female","Male"],
    
        colors=["#e8dbc3","#ffd199"])
plt.show()

# %% [markdown]
# # Preprocessing

# %%
app_df.shape
# Out:
# (16900, 18)

# %%
#Handling missing values Occupation_Type
app_df.drop(columns= ["OCCUPATION_TYPE"], inplace=True)

# %%
app_df.shape
# Out:
# (16900, 17)

# %%
app_df.nunique()
# Out:
# ID                     16900
# CODE_GENDER                2
# FLAG_OWN_CAR               2
# FLAG_OWN_REALTY            2
# CNT_CHILDREN               6
# AMT_INCOME_TOTAL         156
# NAME_INCOME_TYPE           5
# NAME_EDUCATION_TYPE        6
# NAME_FAMILY_STATUS         5
# NAME_HOUSING_TYPE          6
# DAYS_BIRTH              2886
# DAYS_EMPLOYED           1689
# FLAG_MOBIL                 1
# FLAG_WORK_PHONE            2
# FLAG_PHONE                 2
# FLAG_EMAIL                 2
# CNT_FAM_MEMBERS            6
# dtype: int64

# %%
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16900 entries, 0 to 16899
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   16900 non-null  int64
#  1   CODE_GENDER          16900 non-null  object
#  2   FLAG_OWN_CAR         16900 non-null  object
#  3   FLAG_OWN_REALTY      16900 non-null  object
#  4   CNT_CHILDREN         16900 non-null  int64
#  5   AMT_INCOME_TOTAL     16900 non-null  float64
#  6   NAME_INCOME_TYPE     16900 non-null  object
#  7   NAME_EDUCATION_TYPE  16900 non-null  object
#  8   NAME_FAMILY_STATUS   16899 non-null  object
#  9   NAME_HOUSING_TYPE    16899 non-null  object
#  10  DAYS_BIRTH           16899 non-null  float64
#  11  DAYS_EMPLOYED        16899 non-null  float64
#  12  FLAG_MOBIL           16899 non-null  float64
#  13  FLAG_WORK_PHONE      16899 non-null  float64
#  14  FLAG_PHONE           16899 non-null  float64
# ...

# %%
sns.boxplot(y=app_df["AMT_INCOME_TOTAL"])
# Out:
# <Axes: ylabel='AMT_INCOME_TOTAL'>

# %%
#cek outlier hanya pada kolom AMT_INCOME_TOTAL, tidak perlu dibersihkan

# %%
app_df["FLAG_EMAIL"].unique()
# Out:
# array([ 0.,  1., nan])

# %%
#lakukan encoding dulu

# %%
from sklearn.preprocessing import LabelEncoder

# %%
#encoding label, binary 1 dan 0
le = LabelEncoder()
le.fit(app_df["CODE_GENDER"].drop_duplicates())
app_df["CODE_GENDER"] = le.transform(app_df["CODE_GENDER"])

le.fit(app_df["FLAG_OWN_CAR"].drop_duplicates())
app_df["FLAG_OWN_CAR"] = le.transform(app_df["FLAG_OWN_CAR"])

le.fit(app_df["FLAG_OWN_REALTY"].drop_duplicates())
app_df["FLAG_OWN_REALTY"] = le.transform(app_df["FLAG_OWN_REALTY"])

# %%
#one hot encoding

# %%
app_df.nunique()
# Out:
# ID                     16900
# CODE_GENDER                2
# FLAG_OWN_CAR               2
# FLAG_OWN_REALTY            2
# CNT_CHILDREN               6
# AMT_INCOME_TOTAL         156
# NAME_INCOME_TYPE           5
# NAME_EDUCATION_TYPE        6
# NAME_FAMILY_STATUS         5
# NAME_HOUSING_TYPE          6
# DAYS_BIRTH              2886
# DAYS_EMPLOYED           1689
# FLAG_MOBIL                 1
# FLAG_WORK_PHONE            2
# FLAG_PHONE                 2
# FLAG_EMAIL                 2
# CNT_FAM_MEMBERS            6
# dtype: int64

# %%
app_df["CNT_FAM_MEMBERS"].unique()
# Out:
# array([ 2.,  1.,  5.,  3.,  4.,  6., nan])

# %% [markdown]
# dummies_embark_town = pd.get_dummies(df['embark_town'],prefix='embark_town')
# df = pd.concat([df, dummies_embark_town], axis=1)

# %%
dummies = pd.get_dummies(app_df["NAME_INCOME_TYPE"],prefix="Income_Type")
app_df = pd.concat([app_df, dummies], axis=1)

# %%
dummies = pd.get_dummies(app_df["NAME_EDUCATION_TYPE"],prefix="Name_Education")
app_df = pd.concat([app_df, dummies], axis=1)

# %%
dummies = pd.get_dummies(app_df["NAME_FAMILY_STATUS"],prefix="Family_Status")
app_df = pd.concat([app_df, dummies], axis=1)

# %%
dummies = pd.get_dummies(app_df["NAME_HOUSING_TYPE"],prefix="Housing_Type")
app_df = pd.concat([app_df, dummies], axis=1)

# %%
app_df.head()
# Out:
#         ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804            1             1                1             0
# 1  5008805            1             1                1             0
# 2  5008806            1             1                1             0
# 3  5008808            0             0                1             0
# 4  5008809            0             0                1             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  ...  Family_Status_Married  \
# ...

# %%
app_df.drop(columns= ["NAME_HOUSING_TYPE", "NAME_FAMILY_STATUS", "NAME_EDUCATION_TYPE", "NAME_INCOME_TYPE", "CODE_GENDER",
                     "FLAG_OWN_CAR", "FLAG_OWN_REALTY"], inplace=True)

# %%
app_df.head()
# Out:
#         ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0  5008804             0          427500.0    -12005.0        -4542.0
# 1  5008805             0          427500.0    -12005.0        -4542.0
# 2  5008806             0          112500.0    -21474.0        -1134.0
# 3  5008808             0          270000.0    -19110.0        -3051.0
# 4  5008809             0          270000.0    -19110.0        -3051.0
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  ...  \
# 0         1.0              1.0         0.0         0.0              2.0  ...
# 1         1.0              1.0         0.0         0.0              2.0  ...
# 2         1.0              0.0         0.0         0.0              2.0  ...
# 3         1.0              0.0         1.0         1.0              1.0  ...
# 4         1.0              0.0         1.0         1.0              1.0  ...
#
#    Family_Status_Married  Family_Status_Separated  \
# ...

# %%
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16900 entries, 0 to 16899
# Data columns (total 32 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ID                                            16900 non-null  int64
#  1   CNT_CHILDREN                                  16900 non-null  int64
#  2   AMT_INCOME_TOTAL                              16900 non-null  float64
#  3   DAYS_BIRTH                                    16899 non-null  float64
#  4   DAYS_EMPLOYED                                 16899 non-null  float64
#  5   FLAG_MOBIL                                    16899 non-null  float64
#  6   FLAG_WORK_PHONE                               16899 non-null  float64
#  7   FLAG_PHONE                                    16899 non-null  float64
#  8   FLAG_EMAIL                                    16899 non-null  float64
# ...

# %%
import numpy as np

# %%
# Using pandas timedelta type which eases the conversion to datetime format and years calculation
app_df['AGE'] = np.ceil(pd.to_timedelta(app_df['DAYS_BIRTH'], unit='D').dt.days / -365.25)

# %%
app_df[["DAYS_EMPLOYED"]]
# Out:
#        DAYS_EMPLOYED
# 0            -4542.0
# 1            -4542.0
# 2            -1134.0
# 3            -3051.0
# 4            -3051.0
# ...              ...
# 16895        -4660.0
# 16896        -4660.0
# 16897        -4660.0
# 16898        -4660.0
# 16899            NaN
#
# [16900 rows x 1 columns]

# %%
app_df[["AGE"]]
# Out:
#         AGE
# 0      33.0
# 1      33.0
# 2      59.0
# 3      53.0
# 4      53.0
# ...     ...
# 16895  59.0
# 16896  59.0
# 16897  59.0
# 16898  59.0
# 16899   NaN
#
# [16900 rows x 1 columns]

# %% [markdown]
# tidak dilakukan karena eror pada timestamp
# app_df['YEARS_EMPLOYED'] = np.ceil(pd.to_timedelta(app_df['DAYS_EMPLOYED'], unit='D').dt.days / -365.25)

# %%
app_df.loc[(app_df['DAYS_EMPLOYED'] > 0), 'DAYS_EMPLOYED'] = 0

# %%
app_df["DAYS_EMPLOYED"].unique()
# Out:
# array([-4542., -1134., -3051., ..., -6639., -4660.,    nan])

# %%
app_df['YEARS_EMPLOYED'] = np.ceil(pd.to_timedelta(app_df['DAYS_EMPLOYED'], unit='D').dt.days / -365.25)

# %%
app_df = app_df.drop(columns=['DAYS_BIRTH', 'DAYS_EMPLOYED'])

# %%
#outliers kita skip

# %%
#load 2nd dataset

# %%
credit_df = pd.read_csv('credit_record.csv')

# %%
credit_df.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %%
credit_df = credit_df.replace({'STATUS' :
                                          {'C' : 'Good_Debt',
                                           'X' : 'Good_Debt',
                                           '0' : 'Good_Debt',
                                           '1' : 'Bad_Debt',
                                           '2' : 'Bad_Debt',
                                           '3' : 'Bad_Debt',
                                           '4' : 'Bad_Debt',
                                           '5' : 'Bad_Debt'}})

# %%
credit_df.head()
# Out:
#         ID  MONTHS_BALANCE     STATUS
# 0  5001711               0  Good_Debt
# 1  5001711              -1  Good_Debt
# 2  5001711              -2  Good_Debt
# 3  5001711              -3  Good_Debt
# 4  5001712               0  Good_Debt

# %%
result_df = credit_df.value_counts(subset=['ID', 'STATUS']).unstack(fill_value=0)

# %%
#Classifing clients with good_debt counts greater than bad_debt as eligible and vice-versa
result_df.loc[(result_df['Good_Debt'] > result_df['Bad_Debt']), 'Status'] = 1

# %%
result_df.loc[(result_df['Good_Debt'] <= result_df['Bad_Debt']), 'Status'] = 0

# %%
result_df['Status'] = result_df['Status'].astype(int)

# %%
result_df.head()
# Out:
# STATUS   Bad_Debt  Good_Debt  Status
# ID
# 5001711         0          4       1
# 5001712         0         19       1
# 5001713         0         22       1
# 5001714         0         15       1
# 5001715         0         60       1

# %%
df = app_df.merge(result_df, how='inner', on=['ID'])

# %% [markdown]
# # Visualisasi EDA

# %%
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  ...  FLAG_WORK_PHONE  FLAG_PHONE  \
# ...

# %%
sns.scatterplot(data=df, y="AMT_INCOME_TOTAL", x="CNT_FAM_MEMBERS", hue="Status")
# Out:
# <AxesSubplot:xlabel='CNT_FAM_MEMBERS', ylabel='AMT_INCOME_TOTAL'>

# %%
sns.scatterplot(data=df, y="AGE", x="CNT_FAM_MEMBERS", hue="Status")
# Out:
# <AxesSubplot:xlabel='CNT_FAM_MEMBERS', ylabel='AGE'>

# %%
sns.scatterplot(data=df, y="AGE", x="AMT_INCOME_TOTAL", hue="Status")
# Out:
# <AxesSubplot:xlabel='AMT_INCOME_TOTAL', ylabel='AGE'>

# %%
sns.scatterplot(data=df_2, y="AGE", x="AMT_INCOME_TOTAL", hue="Status")
# Out:
# <AxesSubplot:xlabel='AMT_INCOME_TOTAL', ylabel='AGE'>

# %%
sns.scatterplot(data=df, y="AGE", x="Status")
# Out:
# <AxesSubplot:xlabel='Status', ylabel='AGE'>

# %%
df["AMT_INCOME_TOTAL"].describe()
# Out:
# count    3.645700e+04
# mean     1.866857e+05
# std      1.017892e+05
# min      2.700000e+04
# 25%      1.215000e+05
# 50%      1.575000e+05
# 75%      2.250000e+05
# max      1.575000e+06
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
df["AMT_INCOME_TOTAL"].value_counts()
# Out:
# 135000.0    4309
# 180000.0    3097
# 157500.0    3089
# 112500.0    2956
# 225000.0    2926
#             ...
# 177750.0       1
# 594000.0       1
# 164250.0       1
# 124200.0       1
# 179271.0       1
# Name: AMT_INCOME_TOTAL, Length: 265, dtype: int64

# %%
df[df["AMT_INCOME_TOTAL"] == 177750.0]
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 21100  5090119           F            N               Y             0
#
#        AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE  \
# 21100          177750.0        Pensioner    Higher education
#
#       NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  ...  FLAG_WORK_PHONE  FLAG_PHONE  \
# 21100            Married  House / apartment  ...                0           0
#
#        FLAG_EMAIL  OCCUPATION_TYPE  CNT_FAM_MEMBERS   AGE YEARS_EMPLOYED  \
# 21100           0              NaN              2.0  63.0           -0.0
#
#        Bad_Debt  Good_Debt  Status
# 21100         0          8       1
#
# [1 rows x 23 columns]

# %%
df_2 = df[df["AMT_INCOME_TOTAL"] < 177750.0]

# %%
umur = df[df["AGE"] > 15]

# %%
df["AGE"].value_counts()
# Out:
# 38.0    1200
# 41.0    1154
# 28.0    1129
# 29.0    1120
# 40.0    1092
# 34.0    1060
# 39.0    1058
# 33.0    1039
# 35.0    1036
# 43.0    1028
# 36.0    1020
# 42.0    1016
# 44.0     993
# 31.0     982
# 37.0     969
# 32.0     968
# 30.0     951
# 45.0     939
# 47.0     910
# 52.0     904
# 48.0     899
# 49.0     848
# 55.0     848
# 51.0     844
# 60.0     844
# 58.0     837
# 57.0     792
# 54.0     781
# 61.0     780
# 46.0     774
# 50.0     758
# 59.0     722
# 53.0     718
# 56.0     674
# 63.0     640
# 64.0     567
# 62.0     536
# 27.0     527
# 65.0     520
# 26.0     475
# 25.0     386
# 66.0     339
# 67.0     252
# 24.0     209
# 23.0     152
# 68.0     130
# 69.0      26
# 22.0      10
# 21.0       1
# Name: AGE, dtype: int64

# %%
sns.countplot(x=df["Status"])
# Out:
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %%
## selesai disini visualisasi EDA

# %%
df.head()
# Out:
#         ID  CNT_CHILDREN  AMT_INCOME_TOTAL  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 0  5008804             0          427500.0         1.0              1.0
# 1  5008805             0          427500.0         1.0              1.0
# 2  5008806             0          112500.0         1.0              0.0
# 3  5008808             0          270000.0         1.0              0.0
# 4  5008809             0          270000.0         1.0              0.0
#
#    FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  Income_Type_Commercial associate  \
# 0         0.0         0.0              2.0                                 0
# 1         0.0         0.0              2.0                                 0
# 2         0.0         0.0              2.0                                 0
# 3         1.0         1.0              1.0                                 1
# 4         1.0         1.0              1.0                                 1
#
#    Income_Type_Pensioner  ...  Housing_Type_House / apartment  \
# ...

# %%
f, ax = plt.subplots(figsize=(20,20))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
corr = df.corr().round(2)
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, annot=True, mask=mask, cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
df["Status"].value_counts()
# Out:
# 1    36290
# 0      167
# Name: Status, dtype: int64

# %%
df.head()
# Out:
#         ID  CNT_CHILDREN  AMT_INCOME_TOTAL  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 0  5008804             0          427500.0           1                1
# 1  5008805             0          427500.0           1                1
# 2  5008806             0          112500.0           1                0
# 3  5008808             0          270000.0           1                0
# 4  5008809             0          270000.0           1                0
#
#    FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  Income_Type_Commercial associate  \
# 0           0           0              2.0                                 0
# 1           0           0              2.0                                 0
# 2           0           0              2.0                                 0
# 3           1           1              1.0                                 1
# 4           1           1              1.0                                 1
#
#    Income_Type_Pensioner  ...  Housing_Type_House / apartment  \
# ...

# %%
df = df.drop(columns=["ID","Bad_Debt","Good_Debt"])

# %%
df.head()
# Out:
#    CNT_CHILDREN  AMT_INCOME_TOTAL  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  \
# 0             0          427500.0           1                1           0
# 1             0          427500.0           1                1           0
# 2             0          112500.0           1                0           0
# 3             0          270000.0           1                0           1
# 4             0          270000.0           1                0           1
#
#    FLAG_EMAIL  CNT_FAM_MEMBERS  Income_Type_Commercial associate  \
# 0           0              2.0                                 0
# 1           0              2.0                                 0
# 2           0              2.0                                 0
# 3           1              1.0                                 1
# 4           1              1.0                                 1
#
#    Income_Type_Pensioner  Income_Type_State servant  ...  Family_Status_Widow  \
# ...

# %%
#data imbalance, lakukan SMOTE

# %% [markdown]
# # Split the Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
from sklearn import metrics

from sklearn.metrics import roc_auc_score,f1_score, recall_score, precision_score

# %%
X = df.drop(columns = "Status").to_numpy()
y = df[["Status"]].to_numpy()
y = y.reshape(len(y),)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=100)

# %%
y_test
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %% [markdown]
# # Scalling the Data

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Random Forest

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rfc = rfc.predict(X_test)
print(metrics.classification_report(y_test, y_pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.20      0.33         5
#            1       1.00      1.00      1.00      2323
#
#     accuracy                           1.00      2328
#    macro avg       1.00      0.60      0.67      2328
# weighted avg       1.00      1.00      1.00      2328

# %%
precision_score(y_test, y_pred_rfc)
# Out:
# 0.9982810485603781

# %%
RF_recall = recall_score(y_test, y_pred_rfc)
RF_recall
# Out:
# 1.0

# %%
AUC = roc_auc_score(y_test, y_pred_rfc)
f1 = f1_score(y_test, y_pred_rfc)
Pre = precision_score(y_test, y_pred_rfc)
RS = recall_score(y_test, y_pred_rfc)

print("nilai AUC : ",round(AUC,2))
print("nilai F1 : ",round(f1,2))
print("nilai RS : ",round(RS,2))
print("nilai Pre : ",round(Pre,2))
# Out:
# nilai AUC :  0.6
# nilai F1 :  1.0
# nilai RS :  1.0
# nilai Pre :  1.0

# %% [markdown]
# # Decision Tree

# %%
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_tree = tree.predict(X_test)
print(metrics.classification_report(y_test, y_pred_tree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80         5
#            1       1.00      1.00      1.00      2323
#
#     accuracy                           1.00      2328
#    macro avg       0.90      0.90      0.90      2328
# weighted avg       1.00      1.00      1.00      2328

# %%
precision_score(y_test, y_pred_tree)
# Out:
# 0.9995695221696083

# %%
DT_recall = recall_score(y_test, y_pred_tree)
DT_recall
# Out:
# 0.9995695221696083

# %% [markdown]
# # Logistic Regression

# %%
logis = LogisticRegression()
logis.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_logis = logis.predict(X_test)
print(metrics.classification_report(y_test, y_pred_logis))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75         5
#            1       1.00      1.00      1.00      2323
#
#     accuracy                           1.00      2328
#    macro avg       1.00      0.80      0.87      2328
# weighted avg       1.00      1.00      1.00      2328

# %%
LR_recall = recall_score(y_test, y_pred_logis)
recall_score(y_test, y_pred_logis)
# Out:
# 1.0

# %% [markdown]
# # Catboost

# %%
# !pip3 install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 9.9 MB/s eta 0:00:00
# ...

# %%
import catboost as ctb
model_CBC = ctb.CatBoostClassifier()
model_CBC.fit(X_train, y_train)
# Out:
# Learning rate set to 0.026711
# 0:	learn: 0.6081854	total: 51.3ms	remaining: 51.3s
# 1:	learn: 0.5396941	total: 54.6ms	remaining: 27.3s
# 2:	learn: 0.4636966	total: 57.9ms	remaining: 19.2s
# 3:	learn: 0.4105939	total: 61.1ms	remaining: 15.2s
# 4:	learn: 0.3647243	total: 64.2ms	remaining: 12.8s
# 5:	learn: 0.3233268	total: 67.5ms	remaining: 11.2s
# 6:	learn: 0.2883485	total: 71.1ms	remaining: 10.1s
# 7:	learn: 0.2549386	total: 74.3ms	remaining: 9.22s
# 8:	learn: 0.2248643	total: 77.7ms	remaining: 8.55s
# 9:	learn: 0.2000988	total: 80.8ms	remaining: 8s
# 10:	learn: 0.1770505	total: 84.3ms	remaining: 7.58s
# 11:	learn: 0.1593279	total: 87.8ms	remaining: 7.23s
# 12:	learn: 0.1442135	total: 91.1ms	remaining: 6.91s
# 13:	learn: 0.1282149	total: 93.8ms	remaining: 6.6s
# 14:	learn: 0.1133679	total: 97.2ms	remaining: 6.38s
# 15:	learn: 0.1028932	total: 101ms	remaining: 6.18s
# 16:	learn: 0.0906286	total: 104ms	remaining: 6.01s
# 17:	learn: 0.0809690	total: 107ms	remaining: 5.85s
# ...

# %%
y_pred_logis = model_CBC.predict(X_test)
print(metrics.classification_report(y_test, y_pred_logis))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67         5
#            1       1.00      1.00      1.00      2323
#
#     accuracy                           1.00      2328
#    macro avg       0.87      0.80      0.83      2328
# weighted avg       1.00      1.00      1.00      2328

# %%
CBC_recall = recall_score(y_test, y_pred_logis)
recall_score(y_test, y_pred_logis)
# Out:
# 0.9995695221696083

# %% [markdown]
# # With Balanced Data

# %%
from imblearn import under_sampling, over_sampling

# %%
sm = over_sampling.SMOTE(random_state=42)

X = df.drop(['Status'],axis = 1)
Y = df['Status']
X_sm, y_sm = sm.fit_resample(X, Y)

print(f'''Shape of X before SMOTE: {X.shape}
Shape of X after SMOTE: {X_sm.shape}''')

print('\nBalance of positive and negative classes (%):')
y_sm.value_counts(normalize=True) * 100
# Out:
# Shape of X before SMOTE: (36457, 30)
# Shape of X after SMOTE: (72580, 30)
#
# Balance of positive and negative classes (%):
# 1    50.0
# 0    50.0
# Name: Status, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.25, random_state=42)

# %% [markdown]
# # Random Forest

# %%
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
preds = model.predict(X_test)

# %%
print('Akurasi',accuracy_score(y_test, preds))
# Out:
# Akurasi 0.9964177459355195

# %% [markdown]
# rfc = RandomForestClassifier()
# rfc.fit(X_train, y_train)

# %% [markdown]
# y_pred_rfc = rfc.predict(X_test)
# print(metrics.classification_report(y_test, y_pred_rfc))

# %%
print(metrics.classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9071
#            1       1.00      1.00      1.00      9074
#
#     accuracy                           1.00     18145
#    macro avg       1.00      1.00      1.00     18145
# weighted avg       1.00      1.00      1.00     18145

# %%
model_CBC = ctb.CatBoostClassifier()
model_CBC.fit(X_train, y_train)
# Out:
# Learning rate set to 0.056775
# 0:	learn: 0.6366685	total: 14ms	remaining: 14s
# 1:	learn: 0.5896573	total: 26.7ms	remaining: 13.3s
# 2:	learn: 0.5619755	total: 42.7ms	remaining: 14.2s
# 3:	learn: 0.5405368	total: 54.7ms	remaining: 13.6s
# 4:	learn: 0.4965302	total: 66.9ms	remaining: 13.3s
# 5:	learn: 0.4694376	total: 78.2ms	remaining: 13s
# 6:	learn: 0.4564310	total: 89.1ms	remaining: 12.6s
# 7:	learn: 0.4455024	total: 100ms	remaining: 12.4s
# 8:	learn: 0.4317598	total: 112ms	remaining: 12.3s
# 9:	learn: 0.4219328	total: 124ms	remaining: 12.3s
# 10:	learn: 0.4130421	total: 135ms	remaining: 12.2s
# 11:	learn: 0.3917648	total: 147ms	remaining: 12.1s
# 12:	learn: 0.3768322	total: 160ms	remaining: 12.1s
# 13:	learn: 0.3673188	total: 173ms	remaining: 12.2s
# 14:	learn: 0.3594390	total: 188ms	remaining: 12.4s
# 15:	learn: 0.3454337	total: 208ms	remaining: 12.8s
# 16:	learn: 0.3384658	total: 225ms	remaining: 13s
# 17:	learn: 0.3269222	total: 241ms	remaining: 13.2s
# ...

# %%
y_pred_logis = model_CBC.predict(X_test)
print(metrics.classification_report(y_test, y_pred_logis))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9071
#            1       1.00      1.00      1.00      9074
#
#     accuracy                           1.00     18145
#    macro avg       1.00      1.00      1.00     18145
# weighted avg       1.00      1.00      1.00     18145

# %% [markdown]
# # Feature Importance

# %%
feature_index = df.columns

# %%
feature_index = feature_index.drop("Status")

# %%
plt.style.use("seaborn")
feature_importances = pd.DataFrame(rfc.feature_importances_,
                                   index =feature_index,
                                   columns=['importance']).sort_values('importance', ascending=False)
feature_importances

fig, ax = plt.subplots(1,1, figsize=(30,30))
sns.barplot(y='importance', x='index', color='#FFAEB9',data=feature_importances.reset_index())
# Out:
# <AxesSubplot:xlabel='index', ylabel='importance'>
